# %%
import cv2
import numpy as np
import pywt
import matplotlib.pyplot as plt
img = cv2.imread('eagle.png', 0) # flag 0 reads as grayscale
print(img.shape)
noise = np.random.rand(*img.shape) * 0.5 * 255
noisy_img = img + noise
cv2.normalize(noisy_img, noisy_img, 255, 0)
# Out:
# (174, 174)
# array([[1.90080135, 1.23507766, 1.75785877, ..., 1.62981312, 1.32999188,
#         1.24910539],
#        [1.20665567, 1.56048888, 1.73098069, ..., 0.99913065, 1.55501703,
#         1.77769895],
#        [1.71312724, 1.1944354 , 1.58558453, ..., 1.23666633, 1.09745453,
#         1.20737873],
#        ...,
#        [1.84205002, 1.2629941 , 1.63771846, ..., 1.67789836, 1.78707158,
#         1.99361489],
#        [1.27809964, 1.58369085, 1.42033106, ..., 1.85770488, 1.4846186 ,
#         1.40301186],
#        [1.34970701, 1.77463837, 1.65226084, ..., 1.73779322, 1.95867837,
#         1.49284428]])

# %%
plt.imshow(img)

# %%
plt.imshow(noisy_img)

# %%
img_mean = cv2.blur(img, (1, 1))
plt.imshow(img_mean)
