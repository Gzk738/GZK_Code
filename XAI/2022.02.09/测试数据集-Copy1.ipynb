# %%
import ast
with open(r"answers.txt")as f:
    lines = f.readlines()
#删除所有的空行
for line in lines:
    if line == '\n' or len(line) == 0:
        lines.remove(line)
#删除最后得回车换行符
lines = [line[:len(line) - 1] for line in lines]
print(lines[:6])
ids = []
truths = []
answers = []
atributions = []
foeword_atten = []
backword_atten = []

for i in range(len(lines)):
    try:
        if i % 6 == 0 and i != 0:
            ids.append(lines[i - 6])
            truths.append(lines[i - 5])
            answers.append(ast.literal_eval(lines[i - 4]))
            atributions.append(lines[i - 3])
            foeword_atten.append(lines[i - 2])
            backword_atten.append(lines[i - 1])
    except:
        pass

def normalize_text(s):
    """Removing articles and punctuation, and standardizing whitespace are all typical text processing steps."""
    import string, re

    def remove_articles(text):
        regex = re.compile(r"\b(a|an|the)\b", re.UNICODE)
        return re.sub(regex, " ", text)

    def white_space_fix(text):
        return " ".join(text.split())

    def remove_punc(text):
        exclude = set(string.punctuation)
        return "".join(ch for ch in text if ch not in exclude)

    def lower(text):
        return text.lower()

    return white_space_fix(remove_articles(remove_punc(lower(s))))


def compute_exact_match(prediction, truth):
    return int(normalize_text(prediction) == normalize_text(truth))

def compute_f1(prediction, truth):
    pred_tokens = normalize_text(prediction).split()
    truth_tokens = normalize_text(truth).split()

    # if either the prediction or the truth is no-answer then f1 = 1 if they agree, 0 otherwise
    if len(pred_tokens) == 0 or len(truth_tokens) == 0:
        return int(pred_tokens == truth_tokens)

    common_tokens = set(pred_tokens) & set(truth_tokens)

    # if there are no common tokens then f1 = 0
    if len(common_tokens) == 0:
        return 0

    prec = len(common_tokens) / len(pred_tokens)
    rec = len(common_tokens) / len(truth_tokens)

    return 2 * (prec * rec) / (prec + rec)



acc = 0
temp = 0
for i in range((965)):
    f1 = 0
    f1 = compute_f1(answers[i][0], truths[i])
    acc += f1
    temp +=1
    print(answers[i][0])
    print(temp,"--",f1, "*"*144)
    print(truths[i])

print(acc/temp)

# %%
import ast
with open(r"answers.txt")as f:
    lines = f.readlines()
#删除所有的空行
for line in lines:
    if line == '\n' or len(line) == 0:
        lines.remove(line)
#删除最后得回车换行符
lines = [line[:len(line) - 1] for line in lines]
print(lines[:6])
ids = []
truths = []
answers = []
atributions = []
foeword_atten = []
backword_atten = []

for i in range(len(lines)):
    try:
        if i % 6 == 0 and i != 0:
            ids.append(lines[i - 6])
            truths.append(lines[i - 5])
            answers.append(ast.literal_eval(lines[i - 4]))
            atributions.append(lines[i - 3])
            foeword_atten.append(lines[i - 2])
            backword_atten.append(lines[i - 1])
    except:
        pass

def normalize_text(s):
    """Removing articles and punctuation, and standardizing whitespace are all typical text processing steps."""
    import string, re

    def remove_articles(text):
        regex = re.compile(r"\b(a|an|the)\b", re.UNICODE)
        return re.sub(regex, " ", text)

    def white_space_fix(text):
        return " ".join(text.split())

    def remove_punc(text):
        exclude = set(string.punctuation)
        return "".join(ch for ch in text if ch not in exclude)

    def lower(text):
        return text.lower()

    return white_space_fix(remove_articles(remove_punc(lower(s))))


def compute_exact_match(prediction, truth):
    return int(normalize_text(prediction) == normalize_text(truth))

def compute_f1(prediction, truth):
    pred_tokens = normalize_text(prediction).split()
    truth_tokens = normalize_text(truth).split()

    # if either the prediction or the truth is no-answer then f1 = 1 if they agree, 0 otherwise
    if len(pred_tokens) == 0 or len(truth_tokens) == 0:
        return int(pred_tokens == truth_tokens)

    common_tokens = set(pred_tokens) & set(truth_tokens)

    # if there are no common tokens then f1 = 0
    if len(common_tokens) == 0:
        return 0

    prec = len(common_tokens) / len(pred_tokens)
    rec = len(common_tokens) / len(truth_tokens)

    return 2 * (prec * rec) / (prec + rec)


best_answersids = []
acc = 0
temp = 0
str_tensor = []
for i in atributions[0:965]:
    value = i.split(",")[::3]
    value = [float(i[8:]) for i in value]
    str_tensor.append((value))



for onetest_answers in str_tensor:
    best_answersids.append(onetest_answers.index(max(onetest_answers)))


for i in range((965)):
    f1 = 0
    f1 = compute_f1(answers[i][best_answersids[i]], truths[i])
    acc += f1
    temp +=1
    print(answers[i][best_answersids[i]])
    print(temp,"--",f1, "*"*144)
    print(truths[i])

print(acc/temp)
# Out:
# ['0', 'Denver Broncos', "['denver broncos', '', 'denver broncos', '', '']", "[tensor(0.0204, device='cuda:0', dtype=torch.float64), tensor(-0.0357, device='cuda:0', dtype=torch.float64), tensor(0.1092, device='cuda:0', dtype=torch.float64), tensor(-0.0344, device='cuda:0', dtype=torch.float64), tensor(-0.0072, device='cuda:0', dtype=torch.float64)]", '[0.9926780462265015, 0.22192904353141785, 0.9735809564590454, 0.24318240582942963, 0.41909438371658325]', '[0.9967849254608154, 0.21819590032100677, 0.9769585728645325, 0.3430425524711609, 0.2676049768924713]']
# denver broncos
# 1 -- 1.0 ************************************************************************************************************************************************
# Denver Broncos
# carolina panthers
# 2 -- 1.0 ************************************************************************************************************************************************
# Carolina Panthers
# levi ' s stadium in the san francisco bay area at santa clara , california
# 3 -- 0.4 ************************************************************************************************************************************************
# Santa Clara, California
# denver broncos
# 4 -- 1.0 ************************************************************************************************************************************************
# Denver Broncos
# gold
# 5 -- 1.0 ************************************************************************************************************************************************
# gold
# american football game to determine the champion of the national football league ( nfl ) for the 2015 season
# 6 -- 0 ************************************************************************************************************************************************
# "golden anniversary"
# february 7 , 2016
# 7 -- 1.0 ************************************************************************************************************************************************
# February 7, 2016
# american football conference
# 8 -- 1.0 ************************************************************************************************************************************************
# American Football Conference
# american football game to determine the champion of the national football league ( nfl ) for the 2015 season
# 9 -- 0 ************************************************************************************************************************************************
# "golden anniversary"
# american football conference
# 10 -- 1.0 ************************************************************************************************************************************************
# American Football Conference
# february 7
# 11 -- 0.8 ************************************************************************************************************************************************
# February 7, 2016
# denver broncos
# 12 -- 1.0 ************************************************************************************************************************************************
# Denver Broncos
# levi ' s stadium
# 13 -- 0.4 ************************************************************************************************************************************************
# Levi's Stadium
# san francisco bay area at santa clara
# 14 -- 0.4444444444444445 ************************************************************************************************************************************************
# Santa Clara
# super bowl 50
# 15 -- 0.6666666666666666 ************************************************************************************************************************************************
# Super Bowl L
# 2016
# 16 -- 0 ************************************************************************************************************************************************
# 2015
# 2016
# 17 -- 0 ************************************************************************************************************************************************
# 2015
# san francisco bay area at santa clara
# 18 -- 0.4444444444444445 ************************************************************************************************************************************************
# Santa Clara
# levi ' s stadium
# 19 -- 0.4 ************************************************************************************************************************************************
# Levi's Stadium
# super bowl 50 ? [SEP] the game was played on february 7 , 2016
# 20 -- 0 ************************************************************************************************************************************************
# 24–10
# february 7 , 2016
# 21 -- 1.0 ************************************************************************************************************************************************
# February 7, 2016
# 2015
# 22 -- 1.0 ************************************************************************************************************************************************
# 2015
# denver broncos
# 23 -- 1.0 ************************************************************************************************************************************************
# Denver Broncos
# carolina panthers
# 24 -- 1.0 ************************************************************************************************************************************************
# Carolina Panthers
# denver broncos
# 25 -- 1.0 ************************************************************************************************************************************************
# Denver Broncos
# 2015
# 26 -- 1.0 ************************************************************************************************************************************************
# 2015
# denver broncos
# 27 -- 1.0 ************************************************************************************************************************************************
# Denver Broncos
# levi ' s stadium in the san francisco bay area at santa clara , california
# 28 -- 0.4 ************************************************************************************************************************************************
# Santa Clara, California.
# super bowl 50
# 29 -- 0.8 ************************************************************************************************************************************************
# Super Bowl
# denver broncos
# 30 -- 1.0 ************************************************************************************************************************************************
# Denver Broncos
# cam newton
# 31 -- 1.0 ************************************************************************************************************************************************
# Cam Newton
# eight
# 32 -- 0 ************************************************************************************************************************************************
# 8
# 1995
# 33 -- 1.0 ************************************************************************************************************************************************
# 1995
# pittsburgh steelers
# 34 -- 0 ************************************************************************************************************************************************
# Arizona Cardinals
# new england patriots
# 35 -- 1.0 ************************************************************************************************************************************************
# New England Patriots
# arizona cardinals
# 36 -- 1.0 ************************************************************************************************************************************************
# Arizona Cardinals
# panthers
# 37 -- 0 ************************************************************************************************************************************************
# New England Patriots
# arizona cardinals
# 38 -- 0 ************************************************************************************************************************************************
# New England Patriots
# four
# 39 -- 1.0 ************************************************************************************************************************************************
# four
# cam newton
# 40 -- 1.0 ************************************************************************************************************************************************
# Cam Newton
# 15 – 1
# 41 -- 0 ************************************************************************************************************************************************
# 15–1
# cam newton
# 42 -- 1.0 ************************************************************************************************************************************************
# Cam Newton
# 12 – 4 record
# 43 -- 0 ************************************************************************************************************************************************
# 12–4
# four
# 44 -- 0 ************************************************************************************************************************************************
# 4
# new england patriots
# 45 -- 1.0 ************************************************************************************************************************************************
# New England Patriots
# cam newton
# 46 -- 1.0 ************************************************************************************************************************************************
# Cam Newton
# dallas cowboys , and pittsburgh steelers
# 47 -- 0 ************************************************************************************************************************************************
# Arizona Cardinals
# eight
# 48 -- 0 ************************************************************************************************************************************************
# 2
# arizona cardinals
# 49 -- 0 ************************************************************************************************************************************************
# New England Patriots
# cam newton
# 50 -- 1.0 ************************************************************************************************************************************************
# Cam Newton
# new england patriots
# 51 -- 1.0 ************************************************************************************************************************************************
# New England Patriots
# arizona cardinals
# 52 -- 1.0 ************************************************************************************************************************************************
# Arizona Cardinals
# cam newton
# 53 -- 1.0 ************************************************************************************************************************************************
# Cam Newton
# arizona cardinals
# 54 -- 1.0 ************************************************************************************************************************************************
# Arizona Cardinals
# 1995
# 55 -- 1.0 ************************************************************************************************************************************************
# 1995.
# von miller
# 56 -- 1.0 ************************************************************************************************************************************************
# Von Miller
# two
# 57 -- 0 ************************************************************************************************************************************************
# 2
# the broncos
# 58 -- 1.0 ************************************************************************************************************************************************
# Broncos
# von miller
# 59 -- 0.8 ************************************************************************************************************************************************
# linebacker Von Miller
# five
# 60 -- 0.5 ************************************************************************************************************************************************
# five solo tackles
# newton
# 61 -- 0.2857142857142857 ************************************************************************************************************************************************
# Newton was limited by Denver's defense
# newton
# 62 -- 0.2857142857142857 ************************************************************************************************************************************************
# Newton was limited by Denver's defense
# von miller
# 63 -- 1.0 ************************************************************************************************************************************************
# Von Miller
# three
# 64 -- 1.0 ************************************************************************************************************************************************
# three
# two
# 65 -- 1.0 ************************************************************************************************************************************************
# two
# von miller
# 66 -- 1.0 ************************************************************************************************************************************************
# Von Miller
# linebacker
# 67 -- 1.0 ************************************************************************************************************************************************
# linebacker
# five
# 68 -- 0 ************************************************************************************************************************************************
# 5
# two
# 69 -- 0 ************************************************************************************************************************************************
# 2
# von miller
# 70 -- 1.0 ************************************************************************************************************************************************
# Von Miller
# five
# 71 -- 0 ************************************************************************************************************************************************
# 5
# three
# 72 -- 1.0 ************************************************************************************************************************************************
# three
# newton
# 73 -- 0 ************************************************************************************************************************************************
# a fumble
# von miller
# 74 -- 1.0 ************************************************************************************************************************************************
# Von Miller
# linebacker
# 75 -- 1.0 ************************************************************************************************************************************************
# linebacker
# three
# 76 -- 1.0 ************************************************************************************************************************************************
# three
# von miller
# 77 -- 1.0 ************************************************************************************************************************************************
# Von Miller
# five
# 78 -- 1.0 ************************************************************************************************************************************************
# five
# cbs
# 79 -- 1.0 ************************************************************************************************************************************************
# CBS
# $ 5 million
# 80 -- 1.0 ************************************************************************************************************************************************
# $5 million
# cold ##play
# 81 -- 0 ************************************************************************************************************************************************
# Coldplay
# beyonce and bruno mars
# 82 -- 0.75 ************************************************************************************************************************************************
# Beyoncé and Bruno Mars
#
# 83 -- 0 ************************************************************************************************************************************************
# Super Bowl XLVII
# cbs
# 84 -- 1.0 ************************************************************************************************************************************************
# CBS
# $ 5 million
# 85 -- 1.0 ************************************************************************************************************************************************
# $5 million
# bruno mars
# 86 -- 0 ************************************************************************************************************************************************
# Beyoncé
# bruno mars
# 87 -- 1.0 ************************************************************************************************************************************************
# Bruno Mars
# cold ##play
# 88 -- 0 ************************************************************************************************************************************************
# Coldplay
# cbs
# 89 -- 1.0 ************************************************************************************************************************************************
# CBS
# $ 5 million
# 90 -- 1.0 ************************************************************************************************************************************************
# $5 million
# bruno mars
# 91 -- 1.0 ************************************************************************************************************************************************
# Bruno Mars
# third
# 92 -- 1.0 ************************************************************************************************************************************************
# third
# cbs
# 93 -- 1.0 ************************************************************************************************************************************************
# CBS
# $ 5 million
# 94 -- 1.0 ************************************************************************************************************************************************
# $5 million
# cold ##play
# 95 -- 0 ************************************************************************************************************************************************
# Coldplay
# beyonce and bruno mars
# 96 -- 0.75 ************************************************************************************************************************************************
# Beyoncé and Bruno Mars
# cbs
# 97 -- 1.0 ************************************************************************************************************************************************
# CBS
# cold ##play
# 98 -- 0 ************************************************************************************************************************************************
# Coldplay
# beyonce and bruno mars
# 99 -- 0.75 ************************************************************************************************************************************************
# Beyoncé and Bruno Mars
# super bowl xl ##vi ##i
# 100 -- 0.5 ************************************************************************************************************************************************
# Super Bowl XLVII
# $ 5 million
# 101 -- 1.0 ************************************************************************************************************************************************
# $5 million
# cold ##play
# 102 -- 0 ************************************************************************************************************************************************
# Coldplay
# beyonce and bruno mars
# 103 -- 0.75 ************************************************************************************************************************************************
# Beyoncé and Bruno Mars
# bruno mars
# 104 -- 1.0 ************************************************************************************************************************************************
# Bruno Mars
# roger good ##ell
# 105 -- 0.4 ************************************************************************************************************************************************
# Roger Goodell
# 50th
# 106 -- 0.5 ************************************************************************************************************************************************
# the 50th Super Bowl
# 2012
# 107 -- 1.0 ************************************************************************************************************************************************
# 2012
# roger good ##ell
# 108 -- 0.4 ************************************************************************************************************************************************
# Roger Goodell
# early 2012
# 109 -- 1.0 ************************************************************************************************************************************************
# early 2012
# roger good ##ell
# 110 -- 0.4 ************************************************************************************************************************************************
# Roger Goodell
# roger good ##ell
# 111 -- 0.4 ************************************************************************************************************************************************
# Roger Goodell
# roger good ##ell
# 112 -- 0.4 ************************************************************************************************************************************************
# Roger Goodell
# an important game for us as a league "
# 113 -- 0 ************************************************************************************************************************************************
# spectacular
# spectacular
# 114 -- 1.0 ************************************************************************************************************************************************
# spectacular
# 2012
# 115 -- 1.0 ************************************************************************************************************************************************
# 2012
# new orleans ' mercedes - benz super ##dome
# 116 -- 0.4 ************************************************************************************************************************************************
# New Orleans' Mercedes-Benz Superdome
# miami ' s sun life stadium
# 117 -- 0.6666666666666665 ************************************************************************************************************************************************
# Miami's Sun Life Stadium
# levi ' s stadium
# 118 -- 0.2222222222222222 ************************************************************************************************************************************************
# San Francisco Bay Area's Levi's Stadium
# sun life stadium
# 119 -- 1.0 ************************************************************************************************************************************************
# Sun Life Stadium
# levi ' s stadium
# 120 -- 0.4 ************************************************************************************************************************************************
# Levi's Stadium
# levi ' s stadium
# 121 -- 0.4 ************************************************************************************************************************************************
# Levi's Stadium
# mercedes - benz super ##dome
# 122 -- 0 ************************************************************************************************************************************************
# Mercedes-Benz Superdome
# sun life stadium
# 123 -- 1.0 ************************************************************************************************************************************************
# Sun Life Stadium
# new orleans ' mercedes - benz super ##dome , miami ' s sun life stadium , and the san francisco bay area ' s levi ' s stadium
# 124 -- 0.5142857142857143 ************************************************************************************************************************************************
# New Orleans' Mercedes-Benz Superdome, Miami's Sun Life Stadium, and the San Francisco Bay Area's Levi's Stadium
# three
# 125 -- 1.0 ************************************************************************************************************************************************
# three
# new orleans
# 126 -- 1.0 ************************************************************************************************************************************************
# New Orleans
# sun life stadium
# 127 -- 1.0 ************************************************************************************************************************************************
# Sun Life Stadium
# san francisco
# 128 -- 1.0 ************************************************************************************************************************************************
# San Francisco
# levi ' s stadium
# 129 -- 0.4 ************************************************************************************************************************************************
# Levi's Stadium.
# sun life stadium
# 130 -- 1.0 ************************************************************************************************************************************************
# Sun Life Stadium
# mercedes - benz super ##dome
# 131 -- 0 ************************************************************************************************************************************************
# Mercedes-Benz Superdome
# levi ' s stadium
# 132 -- 0.4 ************************************************************************************************************************************************
# Levi's Stadium.
# october 16 , 2012
# 133 -- 1.0 ************************************************************************************************************************************************
# October 16, 2012
# 10
# 134 -- 1.0 ************************************************************************************************************************************************
# 10
#
# 135 -- 0 ************************************************************************************************************************************************
# Super Bowl XLIV
# 2010
# 136 -- 1.0 ************************************************************************************************************************************************
# 2010
# 1985
# 137 -- 1.0 ************************************************************************************************************************************************
# 1985
# sun life stadium
# 138 -- 1.0 ************************************************************************************************************************************************
# Sun Life Stadium
# october 16 , 2012
# 139 -- 1.0 ************************************************************************************************************************************************
# October 16, 2012
# stadium
# 140 -- 0.6666666666666666 ************************************************************************************************************************************************
# Stanford Stadium
# may 3 , 2013
# 141 -- 1.0 ************************************************************************************************************************************************
# May 3, 2013
# 2010
# 142 -- 1.0 ************************************************************************************************************************************************
# 2010
# 1985
# 143 -- 0 ************************************************************************************************************************************************
# two
# super bowl xl ##iv
# 144 -- 0.5714285714285715 ************************************************************************************************************************************************
# Super Bowl XLIV
# two
# 145 -- 1.0 ************************************************************************************************************************************************
# two
# the league
# 146 -- 0 ************************************************************************************************************************************************
# Florida legislature
# 1985
# 147 -- 1.0 ************************************************************************************************************************************************
# 1985
# miami
# 148 -- 0 ************************************************************************************************************************************************
# New Orleans
# october 16 , 2012
# 149 -- 1.0 ************************************************************************************************************************************************
# October 16, 2012
# two
# 150 -- 0 ************************************************************************************************************************************************
# 10.
# new orleans
# 151 -- 1.0 ************************************************************************************************************************************************
# New Orleans
# 1985
# 152 -- 1.0 ************************************************************************************************************************************************
# 1985
# florida legislature
# 153 -- 1.0 ************************************************************************************************************************************************
# Florida legislature
# may 21 , 2013
# 154 -- 1.0 ************************************************************************************************************************************************
# May 21, 2013
# nfl owners
# 155 -- 1.0 ************************************************************************************************************************************************
# NFL owners
# 2014
# 156 -- 1.0 ************************************************************************************************************************************************
# 2014
# $ 1 . 2 billion
# 157 -- 0.4 ************************************************************************************************************************************************
# $1.2 billion
# san diego
# 158 -- 1.0 ************************************************************************************************************************************************
# San Diego
# boston
# 159 -- 1.0 ************************************************************************************************************************************************
# Boston
# may 21 , 2013
# 160 -- 1.0 ************************************************************************************************************************************************
# May 21, 2013
# $ 1 . 2 billion
# 161 -- 0.4 ************************************************************************************************************************************************
# $1.2 billion
# super bowl xx ##x ##vi ##i
# 162 -- 0.4444444444444444 ************************************************************************************************************************************************
# Super Bowl XXXVII
# san diego
# 163 -- 1.0 ************************************************************************************************************************************************
# San Diego
# 2013
# 164 -- 1.0 ************************************************************************************************************************************************
# 2013
# 2014
# 165 -- 1.0 ************************************************************************************************************************************************
# 2014
# $ 1 . 2 billion
# 166 -- 0.4 ************************************************************************************************************************************************
# $1.2 billion
# 2014
# 167 -- 0 ************************************************************************************************************************************************
# 1985
# super bowl
# 168 -- 0.8 ************************************************************************************************************************************************
# Super Bowl XXXVII
# may 21 , 2013
# 169 -- 1.0 ************************************************************************************************************************************************
# May 21, 2013
# 2014
# 170 -- 1.0 ************************************************************************************************************************************************
# 2014
# 2003
# 171 -- 1.0 ************************************************************************************************************************************************
# 2003
# boston
# 172 -- 1.0 ************************************************************************************************************************************************
# Boston
# 2013
# 173 -- 0.5 ************************************************************************************************************************************************
# May 21, 2013
# 2014
# 174 -- 1.0 ************************************************************************************************************************************************
# 2014.
# $ 1 . 2 billion
# 175 -- 0.4 ************************************************************************************************************************************************
# $1.2 billion
# 2003
# 176 -- 1.0 ************************************************************************************************************************************************
# 2003.
# john fox
# 177 -- 1.0 ************************************************************************************************************************************************
# John Fox
# 50
# 178 -- 0 ************************************************************************************************************************************************
# ten
# six
# 179 -- 1.0 ************************************************************************************************************************************************
# six
# denver broncos
# 180 -- 0 ************************************************************************************************************************************************
# Carolina Panthers
# super bowl 50
# 181 -- 0.6666666666666666 ************************************************************************************************************************************************
# Super Bowl XLVIII
# john fox
# 182 -- 1.0 ************************************************************************************************************************************************
# John Fox
# third
# 183 -- 0 ************************************************************************************************************************************************
# eight
# ten
# 184 -- 1.0 ************************************************************************************************************************************************
# ten
# super bowl 50
# 185 -- 0.6666666666666666 ************************************************************************************************************************************************
# Super Bowl XXXVIII
# six
# 186 -- 1.0 ************************************************************************************************************************************************
# six
# number one
# 187 -- 1.0 ************************************************************************************************************************************************
# number one
# number one
# 188 -- 1.0 ************************************************************************************************************************************************
# number one
# third straight season
# 189 -- 0 ************************************************************************************************************************************************
# Super Bowl XLVIII
# super bowl xx ##x ##vi ##ii
# 190 -- 0.4444444444444444 ************************************************************************************************************************************************
# Super Bowl XXXVIII.
# six
# 191 -- 1.0 ************************************************************************************************************************************************
# six
# third
# 192 -- 0 ************************************************************************************************************************************************
# one
# eight
# 193 -- 0 ************************************************************************************************************************************************
# four
# john fox
# 194 -- 1.0 ************************************************************************************************************************************************
# John Fox
# dean ##gel ##o williams
# 195 -- 0.3333333333333333 ************************************************************************************************************************************************
# DeAngelo Williams
# kelvin benjamin
# 196 -- 1.0 ************************************************************************************************************************************************
# Kelvin Benjamin
# ten
# 197 -- 0 ************************************************************************************************************************************************
# 7
# 1978
# 198 -- 1.0 ************************************************************************************************************************************************
# 1978
# carolina panthers
# 199 -- 1.0 ************************************************************************************************************************************************
# Carolina Panthers
# ten
# 200 -- 1.0 ************************************************************************************************************************************************
# Ten
# eight
# 201 -- 1.0 ************************************************************************************************************************************************
# eight
# kelvin benjamin
# 202 -- 1.0 ************************************************************************************************************************************************
# Kelvin Benjamin
# what year did the league begin having schedules with 16 games in them ? [SEP]
# 203 -- 0 ************************************************************************************************************************************************
# 1978
# 1978
# 204 -- 0 ************************************************************************************************************************************************
# 2009
# 15 – 1
# 205 -- 0 ************************************************************************************************************************************************
# 2011
# a torn ac ##l
# 206 -- 0.4 ************************************************************************************************************************************************
# torn ACL
# kelvin benjamin
# 207 -- 1.0 ************************************************************************************************************************************************
# Kelvin Benjamin
# dean ##gel ##o williams
# 208 -- 0.3333333333333333 ************************************************************************************************************************************************
# DeAngelo Williams
# 2009
# 209 -- 0 ************************************************************************************************************************************************
# 1978
# ten
# 210 -- 1.0 ************************************************************************************************************************************************
# Ten
# the panthers
# 211 -- 0.6666666666666666 ************************************************************************************************************************************************
# Carolina Panthers
# 1978
# 212 -- 1.0 ************************************************************************************************************************************************
# 1978.
# the panthers
# 213 -- 0.6666666666666666 ************************************************************************************************************************************************
# Carolina Panthers
# ten
# 214 -- 1.0 ************************************************************************************************************************************************
# Ten
# two
# 215 -- 0 ************************************************************************************************************************************************
# six
# five
# 216 -- 0 ************************************************************************************************************************************************
# 45
# 10
# 217 -- 1.0 ************************************************************************************************************************************************
# 10
# two
# 218 -- 0 ************************************************************************************************************************************************
# 27
# ryan kali ##l
# 219 -- 0 ************************************************************************************************************************************************
# Greg Olsen
# touchdowns
# 220 -- 0 ************************************************************************************************************************************************
# 45
# 99 . 4
# 221 -- 0 ************************************************************************************************************************************************
# 99.4
# 18
# 222 -- 0 ************************************************************************************************************************************************
# 77 passes
# receivers
# 223 -- 1.0 ************************************************************************************************************************************************
# receivers
# jonathan stewart
# 224 -- 1.0 ************************************************************************************************************************************************
# Jonathan Stewart
# two
# 225 -- 0 ************************************************************************************************************************************************
# six
# cam newton
# 226 -- 1.0 ************************************************************************************************************************************************
# Cam Newton
# 3 , 83 ##7
# 227 -- 0 ************************************************************************************************************************************************
# 3,837
# six
# 228 -- 0 ************************************************************************************************************************************************
# 45
# five
# 229 -- 0 ************************************************************************************************************************************************
# six
# 500
# 230 -- 1.0 ************************************************************************************************************************************************
# 500
# 3 , 83 ##7
# 231 -- 0 ************************************************************************************************************************************************
# 3,837
# 45
# 232 -- 1.0 ************************************************************************************************************************************************
# 45
# 99 . 4
# 233 -- 0 ************************************************************************************************************************************************
# 99.4.
# 39
# 234 -- 1.0 ************************************************************************************************************************************************
# 39
# mario addison
# 235 -- 0 ************************************************************************************************************************************************
# Kawann Short
# mario addison
# 236 -- 0 ************************************************************************************************************************************************
# Kawann Short
# mario addison
# 237 -- 0 ************************************************************************************************************************************************
# Kony Ealy
# mario addison
# 238 -- 0 ************************************************************************************************************************************************
# Luke Kuechly.
# manning
# 239 -- 0 ************************************************************************************************************************************************
# Gary Kubiak
# brock os ##weiler
# 240 -- 0.4 ************************************************************************************************************************************************
# Brock Osweiler
# the broncos
# 241 -- 0 ************************************************************************************************************************************************
# Indianapolis Colts
# afc playoffs
# 242 -- 0 ************************************************************************************************************************************************
# San Diego Chargers
# wade phillips
# 243 -- 1.0 ************************************************************************************************************************************************
# Wade Phillips
# 10
# 244 -- 0 ************************************************************************************************************************************************
# four
# gary ku ##bia ##k
# 245 -- 0.3333333333333333 ************************************************************************************************************************************************
# Gary Kubiak
# the broncos
# 246 -- 0 ************************************************************************************************************************************************
# Indianapolis Colts
# 2015
# 247 -- 0 ************************************************************************************************************************************************
# 39
# partial tear of the plant ##ar fa ##sc ##ii ##tis
# 248 -- 0 ************************************************************************************************************************************************
# plantar fasciitis
# gary ku ##bia ##k
# 249 -- 0.3333333333333333 ************************************************************************************************************************************************
# Gary Kubiak
# manning
# 250 -- 0.6666666666666666 ************************************************************************************************************************************************
# Peyton Manning
# plant ##ar fa ##sc ##ii ##tis
# 251 -- 0 ************************************************************************************************************************************************
# a plantar fasciitis injury
# 39
# 252 -- 1.0 ************************************************************************************************************************************************
# 39
# 12 – 4
# 253 -- 0 ************************************************************************************************************************************************
# four
# manning
# 254 -- 0 ************************************************************************************************************************************************
# John Fox
# manning
# 255 -- 0.6666666666666666 ************************************************************************************************************************************************
# Peyton Manning
# manning
# 256 -- 0 ************************************************************************************************************************************************
# Gary Kubiak
# left
# 257 -- 0.6666666666666666 ************************************************************************************************************************************************
# left foot.
# manning
# 258 -- 0 ************************************************************************************************************************************************
# Wade Phillips
# 67 . 9
# 259 -- 0 ************************************************************************************************************************************************
# 67.9
# 46
# 260 -- 0 ************************************************************************************************************************************************
# 17
# owen daniels
# ...
# Jazdów
# 1300
# 884 -- 1.0 ************************************************************************************************************************************************
# 1300
# 141 ##3
# 885 -- 0 ************************************************************************************************************************************************
# 1413
# 152 ##6
# 886 -- 0 ************************************************************************************************************************************************
# 1526
# the general se ##jm
# 887 -- 0.4 ************************************************************************************************************************************************
# General Sejm
# 156 ##9
# 888 -- 0 ************************************************************************************************************************************************
# 1569
# religious freedom
# 889 -- 1.0 ************************************************************************************************************************************************
# religious freedom
# religious freedom
# 890 -- 0 ************************************************************************************************************************************************
# Due to its central location
# 152 ##9
# 891 -- 0 ************************************************************************************************************************************************
# 1596
# 1816
# 892 -- 0 ************************************************************************************************************************************************
# until 1796
# what kingdom annexed warsaw in 1796 ? [SEP] the royal university of warsaw
# 893 -- 0 ************************************************************************************************************************************************
# Prussia
# napoleon
# 894 -- 0 ************************************************************************************************************************************************
# Napoleon's
# 1806
# 895 -- 0 ************************************************************************************************************************************************
# 1815
# 1816
# 896 -- 1.0 ************************************************************************************************************************************************
# 1816
# 4 august 1915 until november 1918
# 897 -- 0 ************************************************************************************************************************************************
# 1920
# the red army
# 898 -- 1.0 ************************************************************************************************************************************************
# the Red Army
# 1 september 1939
# 899 -- 0.8 ************************************************************************************************************************************************
# September 1939
# general government
# 900 -- 0 ************************************************************************************************************************************************
# a German Nazi colonial administration
# 30 %
# 901 -- 0.4 ************************************************************************************************************************************************
# some 30% of the city
# 19 april 1943
# 902 -- 0.8 ************************************************************************************************************************************************
# April 1943
# almost a month
# 903 -- 1.0 ************************************************************************************************************************************************
# almost a month
# the red army
# 904 -- 1.0 ************************************************************************************************************************************************
# the Red Army
# stalin was hostile to the idea of an independent poland
# 905 -- 1.0 ************************************************************************************************************************************************
# Stalin was hostile to the idea of an independent Poland
# 1 august 1944
# 906 -- 0.8 ************************************************************************************************************************************************
# August 1944
# 63
# 907 -- 0.6666666666666666 ************************************************************************************************************************************************
# 63 days
# between 150 , 000 and 200 , 000
# 908 -- 0.4 ************************************************************************************************************************************************
# between 150,000 and 200,000
# poland
# 909 -- 0 ************************************************************************************************************************************************
# "Bricks for Warsaw"
# what type of housing was erected in warsaw as part of the bricks for warsaw process ? [SEP] the city resumed its role as the capital of poland
# 910 -- 0 ************************************************************************************************************************************************
# prefabricated
# eastern bloc city
# 911 -- 1.0 ************************************************************************************************************************************************
# an Eastern Bloc city
# warsaw ' s historic old town
# 912 -- 0 ************************************************************************************************************************************************
# Palace of Culture and Science
# world heritage list
# 913 -- 0.8571428571428571 ************************************************************************************************************************************************
# UNESCO's World Heritage list
# john paul
# 914 -- 0.8 ************************************************************************************************************************************************
# John Paul II
# anti - communist fe ##r ##vor
# 915 -- 0 ************************************************************************************************************************************************
# growing anti-communist fervor
#
# 916 -- 0 ************************************************************************************************************************************************
# less than a year
# warsaw
# 917 -- 0 ************************************************************************************************************************************************
# Victory Square
# the incentive for the democratic changes
# 918 -- 1.0 ************************************************************************************************************************************************
# incentive for the democratic changes
# 300
# 919 -- 0.6666666666666666 ************************************************************************************************************************************************
# about 300
# 325
# 920 -- 1.0 ************************************************************************************************************************************************
# 325
# vis ##tula river
# 921 -- 0.4 ************************************************************************************************************************************************
# Vistula River
# 138 metres
# 922 -- 0 ************************************************************************************************************************************************
# 452.8 ft
# two
# 923 -- 1.0 ************************************************************************************************************************************************
# two
# warsaw es ##car ##pment
# 924 -- 0 ************************************************************************************************************************************************
# Vistula Valley
# mora ##ine plateau
# 925 -- 0 ************************************************************************************************************************************************
# moraine
# warsaw es ##car ##pment
# 926 -- 0 ************************************************************************************************************************************************
# Vistula River
# warsaw es ##car ##pment
# 927 -- 0.3333333333333333 ************************************************************************************************************************************************
# Warsaw Escarpment
# vis ##tula
# 928 -- 0 ************************************************************************************************************************************************
# moraine
# mainly forested areas
# 929 -- 0 ************************************************************************************************************************************************
# former flooded terraces
# valleys and ground depression ##s
# 930 -- 0.33333333333333337 ************************************************************************************************************************************************
# valleys
# vis ##tula terraces
# 931 -- 0.3333333333333333 ************************************************************************************************************************************************
# plain Vistula terraces
# pine forest
# 932 -- 0.6666666666666666 ************************************************************************************************************************************************
# pine
# turbulent history of the city and country
# 933 -- 0.8 ************************************************************************************************************************************************
# turbulent history of the city
# second world war
# 934 -- 0.8571428571428571 ************************************************************************************************************************************************
# During the Second World War
# after liberation
# 935 -- 1.0 ************************************************************************************************************************************************
# After liberation
# leopold k ##rone ##nberg palace
# 936 -- 0.5 ************************************************************************************************************************************************
# Leopold Kronenberg Palace
#
# 937 -- 0 ************************************************************************************************************************************************
# typical of Eastern bloc countries
# gothic
# 938 -- 1.0 ************************************************************************************************************************************************
# Gothic
# 1603 – 163 ##9
# 939 -- 0 ************************************************************************************************************************************************
# 14th century
# gothic architecture
# 940 -- 0.5 ************************************************************************************************************************************************
# Masovian gothic
# gothic
# 941 -- 0 ************************************************************************************************************************************************
# Renaissance
# gothic architecture
# 942 -- 0.5 ************************************************************************************************************************************************
# mannerist architecture
# the 17th century
# 943 -- 1.0 ************************************************************************************************************************************************
# 17th century
# later decades of the 17th century
# 944 -- 0 ************************************************************************************************************************************************
# 1688–1692
# neoclassical
# 945 -- 0 ************************************************************************************************************************************************
# rococo
# neoclassical architecture
# 946 -- 1.0 ************************************************************************************************************************************************
# neoclassical architecture
# later decades of the 17th century
# 947 -- 0 ************************************************************************************************************************************************
# 1775–1795
# late 19th - century architecture
# 948 -- 0 ************************************************************************************************************************************************
# bourgeois
# many have been poorly maintained
# 949 -- 0 ************************************************************************************************************************************************
# not restored by the communist authorities
# socialist realism
# 950 -- 1.0 ************************************************************************************************************************************************
# socialist realism
# warsaw university of technology building
# 951 -- 1.0 ************************************************************************************************************************************************
# Warsaw University of Technology building
# the most distinctive buildings
# 952 -- 1.0 ************************************************************************************************************************************************
# the most distinctive buildings
# the warsaw citadel
# 953 -- 0 ************************************************************************************************************************************************
# many places
# paw ##ia ##k
# 954 -- 0 ************************************************************************************************************************************************
# Pawiak
# warsaw
# 955 -- 0.6666666666666666 ************************************************************************************************************************************************
# The Warsaw Citadel
# the children who served as messengers and front ##line troops in the warsaw uprising
# 956 -- 0.15384615384615385 ************************************************************************************************************************************************
# children
# the warsaw citadel
# 957 -- 0.4 ************************************************************************************************************************************************
# Warsaw Uprising Monument
# green
# 958 -- 1.0 ************************************************************************************************************************************************
# green
# pr ##aga park
# 959 -- 0 ************************************************************************************************************************************************
# New Orangery
# pr ##aga park
# 960 -- 0 ************************************************************************************************************************************************
# Pole Mokotowskie
# pr ##aga park
# 961 -- 0.4 ************************************************************************************************************************************************
# Park Ujazdowski
# 1927
# 962 -- 1.0 ************************************************************************************************************************************************
# 1927
# flora
# 963 -- 0 ************************************************************************************************************************************************
# location of Warsaw
# southern city border
# 964 -- 0 ************************************************************************************************************************************************
# within the borders of Warsaw
# masovian prime ##val forest
# 965 -- 0.5714285714285715 ************************************************************************************************************************************************
# Masovian Primeval Forest
# 0.5209374076091539
