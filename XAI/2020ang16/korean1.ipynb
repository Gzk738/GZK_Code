# %%
from transformers import ElectraTokenizer, ElectraForQuestionAnswering#, pipelines
import re
from pprint import pprint

# tokenizer = ElectraTokenizer.from_pretrained("monologg/koelectra-small-v2-distilled-korquad-384")
# model = ElectraForQuestionAnswering.from_pretrained("monologg/koelectra-small-v2-distilled-korquad-384")

# qa = pipelines("question-answering", tokenizer=tokenizer, model=model)

# pprint(qa({
#     "question": "한국의 대통령은 누구인가?",
#     "context": "문재인 대통령은 28일 서울 코엑스에서 열린 ‘데뷰 (Deview) 2019’ 행사에 참석해 젊은 개발자들을 격려하면서 우리 정부의 인공지능 기본구상을 내놓았다.",
# }))

import os
import sys

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import torch
import torch.nn as nn

from transformers import BertTokenizer, BertForQuestionAnswering, BertConfig
from transformers import ElectraModel, ElectraTokenizer
from captum.attr import visualization as viz
from captum.attr import IntegratedGradients, LayerConductance, LayerIntegratedGradients
from captum.attr import configure_interpretable_embedding_layer, remove_interpretable_embedding_layer

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# replace <PATH-TO-SAVED-MODEL> with the real path of the saved model

model_path = 'bert-base-uncased'

# load model
#model = BertForQuestionAnswering.from_pretrained('bert-large-uncased-whole-word-masking-finetuned-squad')
#model.to(device)
#model.eval()
#model.zero_grad()




# load tokenizer
#tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

tokenizer = ElectraTokenizer.from_pretrained("monologg/koelectra-small-v2-distilled-korquad-384")
model = ElectraForQuestionAnswering.from_pretrained("monologg/koelectra-small-v2-distilled-korquad-384")
model.to(device)
model.eval()
model.zero_grad()

def predict(inputs, token_type_ids=None, position_ids=None, attention_mask=None):
    return model(inputs, token_type_ids=token_type_ids,
                 position_ids=position_ids, attention_mask=attention_mask, )

def squad_pos_forward_func(inputs, token_type_ids=None, position_ids=None, attention_mask=None, position=0):
    pred = predict(inputs,
                   token_type_ids=token_type_ids,
                   position_ids=position_ids,
                   attention_mask=attention_mask)
    pred = pred[position]
    return pred.max(1).values

ref_token_id = tokenizer.pad_token_id # A token used for generating token reference
sep_token_id = tokenizer.sep_token_id # A token used as a separator between question and text and it is also added to the end of the text.
cls_token_id = tokenizer.cls_token_id # A token used for prepending to the concatenated question-text word sequence


def construct_input_ref_pair(question, text, ref_token_id, sep_token_id, cls_token_id):
    question_ids = tokenizer.encode(question, add_special_tokens=False)
    text_ids = tokenizer.encode(text, add_special_tokens=False)

    # construct input token ids
    input_ids = [cls_token_id] + question_ids + [sep_token_id] + text_ids + [sep_token_id]

    # construct reference token ids
    ref_input_ids = [cls_token_id] + [ref_token_id] * len(question_ids) + [sep_token_id] + \
                    [ref_token_id] * len(text_ids) + [sep_token_id]

    return torch.tensor([input_ids], device=device), torch.tensor([ref_input_ids], device=device), len(question_ids)


def construct_input_ref_token_type_pair(input_ids, sep_ind=0):
    seq_len = input_ids.size(1)
    token_type_ids = torch.tensor([[0 if i <= sep_ind else 1 for i in range(seq_len)]], device=device)
    ref_token_type_ids = torch.zeros_like(token_type_ids, device=device)  # * -1
    return token_type_ids, ref_token_type_ids


def construct_input_ref_pos_id_pair(input_ids):
    seq_length = input_ids.size(1)
    position_ids = torch.arange(seq_length, dtype=torch.long, device=device)
    # we could potentially also use random permutation with `torch.randperm(seq_length, device=device)`
    ref_position_ids = torch.zeros(seq_length, dtype=torch.long, device=device)

    position_ids = position_ids.unsqueeze(0).expand_as(input_ids)
    ref_position_ids = ref_position_ids.unsqueeze(0).expand_as(input_ids)
    return position_ids, ref_position_ids


def construct_attention_mask(input_ids):
    return torch.ones_like(input_ids)


def construct_bert_sub_embedding(input_ids, ref_input_ids,
                                 token_type_ids, ref_token_type_ids,
                                 position_ids, ref_position_ids):
    input_embeddings = interpretable_embedding1.indices_to_embeddings(input_ids)
    ref_input_embeddings = interpretable_embedding1.indices_to_embeddings(ref_input_ids)

    input_embeddings_token_type = interpretable_embedding2.indices_to_embeddings(token_type_ids)
    ref_input_embeddings_token_type = interpretable_embedding2.indices_to_embeddings(ref_token_type_ids)

    input_embeddings_position_ids = interpretable_embedding3.indices_to_embeddings(position_ids)
    ref_input_embeddings_position_ids = interpretable_embedding3.indices_to_embeddings(ref_position_ids)

    return (input_embeddings, ref_input_embeddings), \
           (input_embeddings_token_type, ref_input_embeddings_token_type), \
           (input_embeddings_position_ids, ref_input_embeddings_position_ids)


def construct_whole_bert_embeddings(input_ids, ref_input_ids, \
                                    token_type_ids=None, ref_token_type_ids=None, \
                                    position_ids=None, ref_position_ids=None):
    input_embeddings = interpretable_embedding.indices_to_embeddings(input_ids, token_type_ids=token_type_ids,
                                                                     position_ids=position_ids)
    ref_input_embeddings = interpretable_embedding.indices_to_embeddings(ref_input_ids, token_type_ids=token_type_ids,
                                                                         position_ids=position_ids)

    return input_embeddings, ref_input_embeddings


# question, text = "What is important to us?", "It is important to us to include, empower and support humans of all kinds."

def get_posneg(all_tokens, attributions_start_sum):
    positive = []
    negative = []
    neutral = []
    for i, j in enumerate(attributions_start_sum):
        if j > 0:
            positive.append(i)
            # print('positive:',j)
        ##print(all_tokens[i])
        elif j < 0:
            negative.append(i)
            # print('negative:',j)
            # print(all_tokens[i])
        elif j == 0:
            neutral.append(i)

    s_pos = ''
    s_neg = ''

    # print(len(attributions_start_sum))
    # print(len(positive))
    # print(len(negative))

    for i in positive:
        s_pos += all_tokens[i] + ' '
    print("positive :", s_pos)
    for i in negative:
        s_neg += all_tokens[i] + ' '
    print("negative :", s_neg)
    return positive, negative, neutral
def summarize_attributions(attributions):
    attributions = attributions.sum(dim=-1).squeeze(0)
    attributions = attributions / torch.norm(attributions)
    return attributions
def explain(input_ids, ref_input_ids, token_type_ids, position_ids, attention_mask, start_scores, end_scores,
            ground_truth, all_tokens, ):
    lig = LayerIntegratedGradients(squad_pos_forward_func, model.electra.embeddings)

    attributions_start, delta_start = lig.attribute(inputs=input_ids,
                                                    baselines=ref_input_ids,
                                                    additional_forward_args=(
                                                        token_type_ids, position_ids, attention_mask, 0),
                                                    return_convergence_delta=True)
    attributions_end, delta_end = lig.attribute(inputs=input_ids, baselines=ref_input_ids,
                                                additional_forward_args=(
                                                    token_type_ids, position_ids, attention_mask, 1),
                                                return_convergence_delta=True)

    attributions_start_sum = summarize_attributions(attributions_start)
    attributions_end_sum = summarize_attributions(attributions_end)
    # storing couple samples in an array for visualization purposes
    start_position_vis = viz.VisualizationDataRecord(
        attributions_start_sum,
        torch.max(torch.softmax(start_scores[0], dim=0)),
        torch.argmax(start_scores),
        torch.argmax(start_scores),
        str(ground_truth),
        attributions_start_sum.sum(),
        all_tokens,
        delta_start)

    end_position_vis = viz.VisualizationDataRecord(
        attributions_end_sum,
        torch.max(torch.softmax(end_scores[0], dim=0)),
        torch.argmax(end_scores),
        torch.argmax(end_scores),
        str(ground_truth),
        attributions_end_sum.sum(),
        all_tokens,
        delta_end)
    print(all_tokens)
    print('\033[1m', 'Visualizations For Start Position', '\033[0m')
    viz.visualize_text([start_position_vis])

    print('\033[1m', 'Visualizations For End Position', '\033[0m')

    print("attributions_start_sum:   ", len(attributions_start_sum))
    print("all tokens:    ", len(all_tokens))

    return all_tokens, attributions_start_sum
#start_scores, end_scores = predict(input_ids, \
#                                   token_type_ids=token_type_ids, \
#                                   position_ids=position_ids, \
#                                   attention_mask=attention_mask)

def predict_qt(question, text):
    input_ids, ref_input_ids, sep_id = construct_input_ref_pair(question, text, ref_token_id, sep_token_id,
                                                                cls_token_id)
    token_type_ids, ref_token_type_ids = construct_input_ref_token_type_pair(input_ids, sep_id)
    position_ids, ref_position_ids = construct_input_ref_pos_id_pair(input_ids)
    attention_mask = construct_attention_mask(input_ids)

    indices = input_ids[0].detach().tolist()
    all_tokens = tokenizer.convert_ids_to_tokens(indices)

    ground_truth = '뉴질랜드'

    a = predict(input_ids, token_type_ids=token_type_ids, position_ids=position_ids, attention_mask=attention_mask)
    # print(a.loss)
    start_scores = a.start_logits
    end_scores = a.end_logits

    print('Question: ', question)
    print('Predicted Answer: ', ' '.join(all_tokens[torch.argmax(start_scores): torch.argmax(end_scores) + 1]))
    return input_ids, ref_input_ids, token_type_ids, position_ids, attention_mask, start_scores, end_scores, ground_truth, all_tokens, sep_id





def pred_explain(question, text):
    input_ids, ref_input_ids, token_type_ids, position_ids, attention_mask, start_scores, end_scores, ground_truth, all_tokens, sep_id= predict_qt(
        text, question)

    all_tokens, attributions_start_sum = explain(input_ids, ref_input_ids, token_type_ids, position_ids, attention_mask,
                                                 start_scores, end_scores, ground_truth, all_tokens, )

    end_score = float(torch.max(torch.softmax(end_scores[0], dim=0)))
    start_score = float(torch.max(torch.softmax(start_scores[0], dim=0)))
    return all_tokens, attributions_start_sum, end_score, start_score, [torch.argmax(start_scores), torch.argmax(end_scores)+1], sep_id



question= "로제는 2016년 8월 걸그룹 Blackpink로 데뷔했을 때 어떤 역할을 했나요?"

text= "로제 (Rosanne Park, 1997년 2월 11일 ~ )은 한국에 거주하는 한국의 뉴질랜드 가수이자 댄서이다. 뉴질랜드에서 태어나 호주에서 성장한 로제는 2012년 오디션을 보고 한국 음반사 YG엔터테인먼트와 계약해 4년 간의 훈련을 받았다. 2016년 8월 걸그룹 블랙핑크의 리드보컬 겸 리드댄서로 데뷔한 그는 2021년 3월 싱글 앨범 R로 데뷔했다. 빌보드 글로벌 200은 솔로이자 그룹의 멤버이자 K팝 솔로이스트가 24시간 동안 가장 많이 본 유튜브 뮤직비디오이다."

acc_s = []
acc_e = []
all_tokens, attributions_start_sum, start_acc, end_acc,  an_index, sep_id = pred_explain(text, question)
print(start_acc, end_acc)
acc_s.append(start_acc)
acc_e.append(end_acc)

for i in range(20):
    positive, negative, neutral = get_posneg(all_tokens, attributions_start_sum)
    min_vlaue = 999
    min_index = 0
    for i in negative:
        if attributions_start_sum[i] < min_vlaue and (i <an_index[0] or i > an_index[1] or i > sep_id):
            min_vlaue = attributions_start_sum[i]
            min_index = i
    print("should delete : ", all_tokens[min_index], min_vlaue, "index = ", min_index)
    all_tokens[min_index] = ''
    retext = ' '.join(all_tokens)

    li_sep = []
    for m in re.finditer(r"SEP", retext):
        li_sep.append(m.start())
        li_sep.append(m.end())
    retext = retext[li_sep[1]+1: li_sep[2] -1]
    retext = re.sub(r' ##', '', retext)
    all_tokens, attributions_start_sum, start_acc, end_acc,  an_index, sep_id= pred_explain(retext, question)
    print(start_acc, end_acc)
    acc_s.append(start_acc)
    acc_e.append(end_acc)
    print(acc_s, acc_e)
print(acc_s, acc_e)
plt.plot(range(len(acc_s)), acc_s)
plt.plot(range(len(acc_s)), acc_e)
sun = []
for i in range(len(acc_s)):
    sun.append((acc_s[i] + acc_e[i])/2)
print(sun)
plt.plot(range(len(acc_s)), sun)
plt.show()
# Out:
# Question:  로제는 2016년 8월 걸그룹 Blackpink로 데뷔했을 때 어떤 역할을 했나요?
# Predicted Answer:  리드 ##보 ##컬 겸 리드 ##댄 ##서
# ['[CLS]', '로', '##제', '##는', '2016', '##년', '8', '##월', '걸그룹', 'Bl', '##ack', '##pi', '##n', '##k', '##로', '데뷔', '##했', '##을', '때', '어떤', '역할', '##을', '했', '##나', '##요', '?', '[SEP]', '로', '##제', '(', 'R', '##os', '##an', '##ne', 'Par', '##k', ',', '1997', '##년', '2', '##월', '11', '##일', '~', ')', '은', '한국', '##에', '거주', '##하', '##는', '한국', '##의', '뉴질랜드', '가수', '##이자', '댄서', '##이', '##다', '.', '뉴질랜드', '##에', '##서', '태어나', '호주', '##에', '##서', '성장', '##한', '로', '##제', '##는', '2012', '##년', '오디션', '##을', '보고', '한국', '음반', '##사', 'YG', '##엔터테인먼트', '##와', '계약', '##해', '4', '##년', '간', '##의', '훈련', '##을', '받', '##았', '##다', '.', '2016', '##년', '8', '##월', '걸그룹', '블랙', '##핑크', '##의', '리드', '##보', '##컬', '겸', '리드', '##댄', '##서', '##로', '데뷔', '##한', '그', '##는', '2021', '##년', '3', '##월', '싱글', '앨범', 'R', '##로', '데뷔', '##했', '##다', '.', '빌보드', '글로벌', '200', '##은', '솔로', '##이자', '그룹', '##의', '멤버', '##이자', 'K', '##팝', '솔로', '##이스트', '##가', '24', '##시간', '동안', '가장', '많이', '본', '유튜브', '뮤직비디오', '##이', '##다', '.', '[SEP]']
#  Visualizations For Start Position
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>103</b></text></td><td><text style="padding-right:2em"><b>103 (0.97)</b></text></td><td><text style="padding-right:2em"><b>뉴질랜드</b></text></td><td><text style="padding-right:2em"><b>3.44</b></text></td><td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [CLS]                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> 로                    </font></mark><mark style="background-color: hsl(120, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> ##제                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##는                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> 2016                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##년                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> 8                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> ##월                    </font></mark><mark style="background-color: hsl(0, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> 걸그룹                    </font></mark><mark style="background-color: hsl(120, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> Bl                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##ack                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> ##pi                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##n                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##k                    </font></mark><mark style="background-color: hsl(0, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##로                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> 데뷔                    </font></mark><mark style="background-color: hsl(120, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> ##했                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> ##을                    </font></mark><mark style="background-color: hsl(120, 75%, 94%); opacity:1.0;                     line-height:1.75 ...
#  Visualizations For End Position
# attributions_start_sum:    154
# all tokens:     154
# 0.9992594122886658 0.9714639782905579
# positive : 로 ##제 ##는 2016 ##년 8 ##월 Bl ##ack ##pi ##n ##k 데뷔 ##했 ##을 때 어떤 역할 했 ##나 ? 로 ##제 R ##os ##an ##ne Par ##k , 1997 ##년 2 ##일 ) 은 한국 ##에 거주 ##하 ##는 ##의 뉴질랜드 댄서 ##다 . 태어나 호주 ##에 ##서 ##한 ##는 2012 ##년 오디션 ##을 한국 ##엔터테인먼트 ##해 4 ##년 간 ##의 훈련 ##을 받 ##았 ##다 . ##년 8 ##월 걸그룹 블랙 ##핑크 ##의 리드 ##보 ##컬 리드 ##댄 ##로 그 ##는 3 ##로 ##했 ##다 . 글로벌 ##은 ##의 ##이자 ##팝 솔로 ##시간 동안 본 ##이 .
# negative : 걸그룹 ##로 ##을 ##요 ( ##월 11 ~ 한국 가수 ##이자 ##이 뉴질랜드 ##에 ##서 성장 로 ##제 보고 음반 ##사 YG ##와 계약 2016 겸 ##서 데뷔 ##한 2021 ##년 ##월 싱글 앨범 R 데뷔 빌보드 200 솔로 ##이자 그룹 멤버 K ##이스트 ##가 24 가장 많이 유튜브 뮤직비디오 ##다
# should delete :  ##이자 tensor(-0.3639, dtype=torch.float64) index =  55
# Question:  로제는 2016년 8월 걸그룹 Blackpink로 데뷔했을 때 어떤 역할을 했나요?
# Predicted Answer:  리드 ##보 ##컬 겸 리드 ##댄 ##서
# ['[CLS]', '로', '##제', '##는', '2016', '##년', '8', '##월', '걸그룹', 'Bl', '##ack', '##pi', '##n', '##k', '##로', '데뷔', '##했', '##을', '때', '어떤', '역할', '##을', '했', '##나', '##요', '?', '[SEP]', '로', '##제', '(', 'R', '##os', '##an', '##ne', 'Par', '##k', ',', '1997', '##년', '2', '##월', '11', '##일', '~', ')', '은', '한국', '##에', '거주', '##하', '##는', '한국', '##의', '뉴질랜드', '가수', '댄서', '##이', '##다', '.', '뉴질랜드', '##에', '##서', '태어나', '호주', '##에', '##서', '성장', '##한', '로', '##제', '##는', '2012', '##년', '오디션', '##을', '보고', '한국', '음반', '##사', 'YG', '##엔터테인먼트', '##와', '계약', '##해', '4', '##년', '간', '##의', '훈련', '##을', '받', '##았', '##다', '.', '2016', '##년', '8', '##월', '걸그룹', '블랙', '##핑크', '##의', '리드', '##보', '##컬', '겸', '리드', '##댄', '##서', '##로', '데뷔', '##한', '그', '##는', '2021', '##년', '3', '##월', '싱글', '앨범', 'R', '##로', '데뷔', '##했', '##다', '.', '빌보드', '글로벌', '200', '##은', '솔로', '##이자', '그룹', '##의', '멤버', '##이자', 'K', '##팝', '솔로', '##이스트', '##가', '24', '##시간', '동안', '가장', '많이', '본', '유튜브', '뮤직비디오', '##이', '##다', '.', '[SEP]']
#  Visualizations For Start Position
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>102</b></text></td><td><text style="padding-right:2em"><b>102 (0.95)</b></text></td><td><text style="padding-right:2em"><b>뉴질랜드</b></text></td><td><text style="padding-right:2em"><b>4.55</b></text></td><td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [CLS]                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> 로                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##제                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> ##는                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> 2016                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> ##년                    </font></mark><mark style="background-color: hsl(120, 75%, 92%); opacity:1.0;                     line-height:1.75"><font color="black"> 8                    </font></mark><mark style="background-color: hsl(120, 75%, 93%); opacity:1.0;                     line-height:1.75"><font color="black"> ##월                    </font></mark><mark style="background-color: hsl(0, 75%, 96%); opacity:1.0;                     line-height:1.75"><font color="black"> 걸그룹                    </font></mark><mark style="background-color: hsl(120, 75%, 95%); opacity:1.0;                     line-height:1.75"><font color="black"> Bl                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> ##ack                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> ##pi                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##n                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> ##k                    </font></mark><mark style="background-color: hsl(0, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##로                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> 데뷔                    </font></mark><mark style="background-color: hsl(120, 75%, 96%); opacity:1.0;                     line-height:1.75"><font color="black"> ##했                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> ##을                    </font></mark><mark style="background-color: hsl(120, 75%, 94%); opacity:1.0;                     line-height:1. ...
#  Visualizations For End Position
# attributions_start_sum:    153
# all tokens:     153
# 0.9988586902618408 0.9473617672920227
# [0.9992594122886658, 0.9988586902618408] [0.9714639782905579, 0.9473617672920227]
# positive : 로 ##제 ##는 2016 ##년 8 ##월 Bl ##ack ##pi ##n ##k 데뷔 ##했 때 어떤 역할 했 ##나 ? 로 ##제 R ##os ##an ##ne Par ##k , 1997 ##년 2 ##일 ~ ) 은 한국 ##에 거주 ##하 ##는 ##의 뉴질랜드 댄서 ##다 . ##서 태어나 호주 ##에 ##서 성장 ##한 ##는 2012 ##년 오디션 ##을 보고 한국 ##사 ##엔터테인먼트 계약 간 ##의 훈련 ##을 받 . ##년 8 블랙 ##핑크 ##의 리드 ##보 ##컬 겸 리드 ##댄 데뷔 그 ##는 3 ##월 싱글 앨범 ##로 ##했 ##다 . 글로벌 ##은 ##의 멤버 ##이자 K ##팝 ##가 ##시간 가장 본 유튜브 ##이 ##다 .
# negative : 걸그룹 ##로 ##을 ##을 ##요 ( ##월 11 한국 가수 ##이 뉴질랜드 ##에 로 ##제 음반 YG ##와 ##해 4 ##년 ##았 ##다 2016 ##월 걸그룹 ##서 ##로 ##한 2021 ##년 R 데뷔 빌보드 200 솔로 ##이자 그룹 솔로 ##이스트 24 동안 많이 뮤직비디오
# should delete :  가수 tensor(-0.1861, dtype=torch.float64) index =  54
# Question:  로제는 2016년 8월 걸그룹 Blackpink로 데뷔했을 때 어떤 역할을 했나요?
# Predicted Answer:  블랙 ##핑크 ##의 리드 ##보 ##컬 겸 리드 ##댄 ##서
# ['[CLS]', '로', '##제', '##는', '2016', '##년', '8', '##월', '걸그룹', 'Bl', '##ack', '##pi', '##n', '##k', '##로', '데뷔', '##했', '##을', '때', '어떤', '역할', '##을', '했', '##나', '##요', '?', '[SEP]', '로', '##제', '(', 'R', '##os', '##an', '##ne', 'Par', '##k', ',', '1997', '##년', '2', '##월', '11', '##일', '~', ')', '은', '한국', '##에', '거주', '##하', '##는', '한국', '##의', '뉴질랜드', '댄서', '##이', '##다', '.', '뉴질랜드', '##에', '##서', '태어나', '호주', '##에', '##서', '성장', '##한', '로', '##제', '##는', '2012', '##년', '오디션', '##을', '보고', '한국', '음반', '##사', 'YG', '##엔터테인먼트', '##와', '계약', '##해', '4', '##년', '간', '##의', '훈련', '##을', '받', '##았', '##다', '.', '2016', '##년', '8', '##월', '걸그룹', '블랙', '##핑크', '##의', '리드', '##보', '##컬', '겸', '리드', '##댄', '##서', '##로', '데뷔', '##한', '그', '##는', '2021', '##년', '3', '##월', '싱글', '앨범', 'R', '##로', '데뷔', '##했', '##다', '.', '빌보드', '글로벌', '200', '##은', '솔로', '##이자', '그룹', '##의', '멤버', '##이자', 'K', '##팝', '솔로', '##이스트', '##가', '24', '##시간', '동안', '가장', '많이', '본', '유튜브', '뮤직비디오', '##이', '##다', '.', '[SEP]']
#  Visualizations For Start Position
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>98</b></text></td><td><text style="padding-right:2em"><b>98 (0.60)</b></text></td><td><text style="padding-right:2em"><b>뉴질랜드</b></text></td><td><text style="padding-right:2em"><b>3.77</b></text></td><td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [CLS]                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> 로                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> ##제                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> ##는                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> 2016                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##년                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> 8                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> ##월                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> 걸그룹                    </font></mark><mark style="background-color: hsl(120, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> Bl                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> ##ack                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> ##pi                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> ##n                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##k                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> ##로                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> 데뷔                    </font></mark><mark style="background-color: hsl(120, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> ##했                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> ##을                    </font></mark><mark style="background-color: hsl(120, 75%, 96%); opacity:1.0;                     line-heig ...
#  Visualizations For End Position
# attributions_start_sum:    152
# all tokens:     152
# 0.9992868304252625 0.6024073362350464
# [0.9992594122886658, 0.9988586902618408, 0.9992868304252625] [0.9714639782905579, 0.9473617672920227, 0.6024073362350464]
# positive : 로 ##제 ##는 2016 ##년 8 ##월 걸그룹 Bl ##ack ##pi ##n ##k 데뷔 ##했 ##을 때 어떤 역할 했 ##나 ? 로 ##제 ( ##os ##an ##ne Par ##k ##년 ##일 ~ ) 은 ##에 거주 ##하 ##는 ##의 뉴질랜드 댄서 ##다 . 태어나 호주 ##에 ##서 성장 ##한 로 ##는 2012 ##년 오디션 ##을 ##사 ##엔터테인먼트 계약 ##해 4 간 ##의 훈련 ##을 받 ##다 . ##년 8 ##월 걸그룹 블랙 ##핑크 ##의 리드 ##보 ##컬 겸 리드 ##댄 ##로 데뷔 ##한 2021 ##년 3 ##월 싱글 앨범 R ##로 데뷔 ##했 ##다 . ##은 ##의 ##이자 ##팝 솔로 ##가 동안 많이 본 유튜브 뮤직비디오 ##이 ##다 .
# negative : ##로 ##을 ##요 R , 1997 2 ##월 11 한국 한국 ##이 뉴질랜드 ##에 ##서 ##제 보고 한국 음반 YG ##와 ##년 ##았 2016 ##서 그 ##는 빌보드 글로벌 200 솔로 ##이자 그룹 멤버 K ##이스트 24 ##시간 가장
# should delete :  뉴질랜드 tensor(-0.1061, dtype=torch.float64) index =  58
# Question:  로제는 2016년 8월 걸그룹 Blackpink로 데뷔했을 때 어떤 역할을 했나요?
# Predicted Answer:  블랙 ##핑크 ##의 리드 ##보 ##컬 겸 리드 ##댄 ##서
# ['[CLS]', '로', '##제', '##는', '2016', '##년', '8', '##월', '걸그룹', 'Bl', '##ack', '##pi', '##n', '##k', '##로', '데뷔', '##했', '##을', '때', '어떤', '역할', '##을', '했', '##나', '##요', '?', '[SEP]', '로', '##제', '(', 'R', '##os', '##an', '##ne', 'Par', '##k', ',', '1997', '##년', '2', '##월', '11', '##일', '~', ')', '은', '한국', '##에', '거주', '##하', '##는', '한국', '##의', '뉴질랜드', '댄서', '##이', '##다', '.', '에서', '태어나', '호주', '##에', '##서', '성장', '##한', '로', '##제', '##는', '2012', '##년', '오디션', '##을', '보고', '한국', '음반', '##사', 'YG', '##엔터테인먼트', '##와', '계약', '##해', '4', '##년', '간', '##의', '훈련', '##을', '받', '##았', '##다', '.', '2016', '##년', '8', '##월', '걸그룹', '블랙', '##핑크', '##의', '리드', '##보', '##컬', '겸', '리드', '##댄', '##서', '##로', '데뷔', '##한', '그', '##는', '2021', '##년', '3', '##월', '싱글', '앨범', 'R', '##로', '데뷔', '##했', '##다', '.', '빌보드', '글로벌', '200', '##은', '솔로', '##이자', '그룹', '##의', '멤버', '##이자', 'K', '##팝', '솔로', '##이스트', '##가', '24', '##시간', '동안', '가장', '많이', '본', '유튜브', '뮤직비디오', '##이', '##다', '.', '[SEP]']
#  Visualizations For Start Position
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>96</b></text></td><td><text style="padding-right:2em"><b>96 (0.98)</b></text></td><td><text style="padding-right:2em"><b>뉴질랜드</b></text></td><td><text style="padding-right:2em"><b>4.29</b></text></td><td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [CLS]                    </font></mark><mark style="background-color: hsl(120, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> 로                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> ##제                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> ##는                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> 2016                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##년                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> 8                    </font></mark><mark style="background-color: hsl(120, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> ##월                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> 걸그룹                    </font></mark><mark style="background-color: hsl(120, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> Bl                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> ##ack                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##pi                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> ##n                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##k                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> ##로                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> 데뷔                    </font></mark><mark style="background-color: hsl(120, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> ##했                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> ##을                    </font></mark><mark style="background-color: hsl(120, 75%, 97%); opacity:1.0;                     line-height:1.75" ...
#  Visualizations For End Position
# attributions_start_sum:    150
# all tokens:     150
# 0.9986371397972107 0.9838355779647827
# [0.9992594122886658, 0.9988586902618408, 0.9992868304252625, 0.9986371397972107] [0.9714639782905579, 0.9473617672920227, 0.6024073362350464, 0.9838355779647827]
# positive : 로 ##제 ##는 2016 ##년 8 ##월 걸그룹 Bl ##ack ##pi ##n ##k 데뷔 ##했 때 어떤 역할 했 ##나 ? 로 ##제 ( ##os ##an ##ne Par ##k , ##년 ##일 ) 은 ##에 거주 ##하 ##는 한국 ##의 뉴질랜드 댄서 ##다 . 에서 태어나 호주 성장 로 2012 ##을 보고 한국 음반 YG ##엔터테인먼트 계약 간 ##의 ##을 받 ##았 ##다 . ##년 8 ##월 걸그룹 블랙 ##의 ##컬 겸 리드 ##댄 ##로 ##한 그 ##는 2021 ##년 3 ##월 싱글 R ##로 데뷔 ##했 ##다 . 빌보드 ##은 ##이자 그룹 ##의 ##이자 솔로 ##가 ##시간 ##이 ##다 .
# negative : ##로 ##을 ##을 ##요 R 1997 2 ##월 11 ~ 한국 ##이 ##에 ##서 ##한 ##제 ##는 ##년 오디션 ##사 ##와 ##해 4 ##년 훈련 2016 ##핑크 리드 ##보 ##서 데뷔 앨범 글로벌 200 솔로 멤버 K ##팝 ##이스트 24 동안 가장 많이 본 유튜브 뮤직비디오
# should delete :  ##에 tensor(-0.0685, dtype=torch.float64) index =  61
# Question:  로제는 2016년 8월 걸그룹 Blackpink로 데뷔했을 때 어떤 역할을 했나요?
# Predicted Answer:  블랙 ##핑크 ##의 리드 ##보 ##컬 겸 리드 ##댄 ##서
# ['[CLS]', '로', '##제', '##는', '2016', '##년', '8', '##월', '걸그룹', 'Bl', '##ack', '##pi', '##n', '##k', '##로', '데뷔', '##했', '##을', '때', '어떤', '역할', '##을', '했', '##나', '##요', '?', '[SEP]', '로', '##제', '(', 'R', '##os', '##an', '##ne', 'Par', '##k', ',', '1997', '##년', '2', '##월', '11', '##일', '~', ')', '은', '한국', '##에', '거주', '##하', '##는', '한국', '##의', '뉴질랜드', '댄서', '##이', '##다', '.', '에서', '태어나', '호주', '서', '성장', '##한', '로', '##제', '##는', '2012', '##년', '오디션', '##을', '보고', '한국', '음반', '##사', 'YG', '##엔터테인먼트', '##와', '계약', '##해', '4', '##년', '간', '##의', '훈련', '##을', '받', '##았', '##다', '.', '2016', '##년', '8', '##월', '걸그룹', '블랙', '##핑크', '##의', '리드', '##보', '##컬', '겸', '리드', '##댄', '##서', '##로', '데뷔', '##한', '그', '##는', '2021', '##년', '3', '##월', '싱글', '앨범', 'R', '##로', '데뷔', '##했', '##다', '.', '빌보드', '글로벌', '200', '##은', '솔로', '##이자', '그룹', '##의', '멤버', '##이자', 'K', '##팝', '솔로', '##이스트', '##가', '24', '##시간', '동안', '가장', '많이', '본', '유튜브', '뮤직비디오', '##이', '##다', '.', '[SEP]']
#  Visualizations For Start Position
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>95</b></text></td><td><text style="padding-right:2em"><b>95 (0.88)</b></text></td><td><text style="padding-right:2em"><b>뉴질랜드</b></text></td><td><text style="padding-right:2em"><b>4.06</b></text></td><td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [CLS]                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> 로                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##제                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##는                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> 2016                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##년                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> 8                    </font></mark><mark style="background-color: hsl(120, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> ##월                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> 걸그룹                    </font></mark><mark style="background-color: hsl(120, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> Bl                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> ##ack                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##pi                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##n                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##k                    </font></mark><mark style="background-color: hsl(0, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##로                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> 데뷔                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> ##했                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> ##을                    </font></mark><mark style="background-color: hsl(120, 75%, 97%); opacity:1.0;                     line-height:1.7 ...
#  Visualizations For End Position
# attributions_start_sum:    149
# all tokens:     149
# 0.9988114833831787 0.8820470571517944
# [0.9992594122886658, 0.9988586902618408, 0.9992868304252625, 0.9986371397972107, 0.9988114833831787] [0.9714639782905579, 0.9473617672920227, 0.6024073362350464, 0.9838355779647827, 0.8820470571517944]
# positive : 로 ##제 ##는 2016 ##년 8 ##월 걸그룹 Bl ##ack ##pi ##n ##k 데뷔 ##했 때 어떤 역할 했 ##나 ##요 ? 로 ##제 ( ##os ##an ##ne Par ##k , ##년 ##일 ) ##에 거주 ##하 ##는 한국 ##의 뉴질랜드 댄서 ##다 . 에서 호주 서 성장 ##한 로 2012 ##년 오디션 ##을 한국 음반 ##사 YG ##와 계약 ##해 간 ##의 ##을 받 ##았 . ##년 8 걸그룹 ##의 ##컬 겸 ##댄 ##로 데뷔 그 ##는 2021 ##년 3 ##월 R ##로 데뷔 ##했 ##다 200 ##은 ##이자 그룹 ##의 멤버 ##이자 ##팝 솔로 ##가 ##시간 많이 ##이 .
# negative : ##로 ##을 ##을 R 1997 2 ##월 11 ~ 은 한국 ##이 태어나 ##제 ##는 보고 ##엔터테인먼트 4 ##년 훈련 ##다 2016 ##월 블랙 ##핑크 리드 ##보 리드 ##서 ##한 싱글 앨범 . 빌보드 글로벌 솔로 K ##이스트 24 동안 가장 본 유튜브 뮤직비디오 ##다
# should delete :  ##는 tensor(-0.1241, dtype=torch.float64) index =  66
# Question:  로제는 2016년 8월 걸그룹 Blackpink로 데뷔했을 때 어떤 역할을 했나요?
# Predicted Answer:  블랙 ##핑크 ##의 리드 ##보 ##컬 겸 리드 ##댄 ##서
# ['[CLS]', '로', '##제', '##는', '2016', '##년', '8', '##월', '걸그룹', 'Bl', '##ack', '##pi', '##n', '##k', '##로', '데뷔', '##했', '##을', '때', '어떤', '역할', '##을', '했', '##나', '##요', '?', '[SEP]', '로', '##제', '(', 'R', '##os', '##an', '##ne', 'Par', '##k', ',', '1997', '##년', '2', '##월', '11', '##일', '~', ')', '은', '한국', '##에', '거주', '##하', '##는', '한국', '##의', '뉴질랜드', '댄서', '##이', '##다', '.', '에서', '태어나', '호주', '서', '성장', '##한', '로', '##제', '2012', '##년', '오디션', '##을', '보고', '한국', '음반', '##사', 'YG', '##엔터테인먼트', '##와', '계약', '##해', '4', '##년', '간', '##의', '훈련', '##을', '받', '##았', '##다', '.', '2016', '##년', '8', '##월', '걸그룹', '블랙', '##핑크', '##의', '리드', '##보', '##컬', '겸', '리드', '##댄', '##서', '##로', '데뷔', '##한', '그', '##는', '2021', '##년', '3', '##월', '싱글', '앨범', 'R', '##로', '데뷔', '##했', '##다', '.', '빌보드', '글로벌', '200', '##은', '솔로', '##이자', '그룹', '##의', '멤버', '##이자', 'K', '##팝', '솔로', '##이스트', '##가', '24', '##시간', '동안', '가장', '많이', '본', '유튜브', '뮤직비디오', '##이', '##다', '.', '[SEP]']
#  Visualizations For Start Position
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>94</b></text></td><td><text style="padding-right:2em"><b>94 (0.56)</b></text></td><td><text style="padding-right:2em"><b>뉴질랜드</b></text></td><td><text style="padding-right:2em"><b>3.64</b></text></td><td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [CLS]                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> 로                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##제                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> ##는                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> 2016                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##년                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> 8                    </font></mark><mark style="background-color: hsl(120, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> ##월                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> 걸그룹                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> Bl                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> ##ack                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> ##pi                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##n                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##k                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> ##로                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> 데뷔                    </font></mark><mark style="background-color: hsl(120, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> ##했                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> ##을                    </font></mark><mark style="background-color: hsl(120, 75%, 97%); opacity:1.0;                     line-height:1 ...
#  Visualizations For End Position
# attributions_start_sum:    148
# all tokens:     148
# 0.9989060163497925 0.562415361404419
# [0.9992594122886658, 0.9988586902618408, 0.9992868304252625, 0.9986371397972107, 0.9988114833831787, 0.9989060163497925] [0.9714639782905579, 0.9473617672920227, 0.6024073362350464, 0.9838355779647827, 0.8820470571517944, 0.562415361404419]
# positive : 로 ##제 ##는 2016 ##년 8 ##월 Bl ##ack ##pi ##n ##k 데뷔 ##했 ##을 때 어떤 역할 했 ##나 ? 로 ( ##os ##an ##ne Par ##k , ##년 2 ##월 ##일 ~ ) 은 ##에 거주 ##하 ##는 한국 ##의 뉴질랜드 댄서 ##다 . 에서 호주 서 성장 ##한 로 2012 오디션 보고 한국 음반 ##사 YG 계약 간 ##의 ##을 받 ##았 ##다 . ##년 ##월 리드 ##보 ##컬 겸 ##댄 ##서 ##한 2021 3 싱글 R ##로 ##했 ##다 . 200 ##은 ##이자 그룹 ##의 ##이자 ##팝 솔로 ##가 24 많이 본 ##이 ##다
# negative : 걸그룹 ##로 ##을 ##요 ##제 R 1997 11 한국 ##이 태어나 ##제 ##년 ##을 ##엔터테인먼트 ##와 ##해 4 ##년 훈련 2016 8 걸그룹 블랙 ##핑크 ##의 리드 ##로 데뷔 그 ##는 ##년 ##월 앨범 데뷔 빌보드 글로벌 솔로 멤버 K ##이스트 ##시간 동안 가장 유튜브 뮤직비디오 .
# should delete :  블랙 tensor(-0.1380, dtype=torch.float64) index =  94
# Question:  로제는 2016년 8월 걸그룹 Blackpink로 데뷔했을 때 어떤 역할을 했나요?
# Predicted Answer:  리드 ##보 ##컬 겸 리드 ##댄 ##서
# ['[CLS]', '로', '##제', '##는', '2016', '##년', '8', '##월', '걸그룹', 'Bl', '##ack', '##pi', '##n', '##k', '##로', '데뷔', '##했', '##을', '때', '어떤', '역할', '##을', '했', '##나', '##요', '?', '[SEP]', '로', '##제', '(', 'R', '##os', '##an', '##ne', 'Par', '##k', ',', '1997', '##년', '2', '##월', '11', '##일', '~', ')', '은', '한국', '##에', '거주', '##하', '##는', '한국', '##의', '뉴질랜드', '댄서', '##이', '##다', '.', '에서', '태어나', '호주', '서', '성장', '##한', '로', '##제', '2012', '##년', '오디션', '##을', '보고', '한국', '음반', '##사', 'YG', '##엔터테인먼트', '##와', '계약', '##해', '4', '##년', '간', '##의', '훈련', '##을', '받', '##았', '##다', '.', '2016', '##년', '8', '##월', '걸그룹', '핑크', '##의', '리드', '##보', '##컬', '겸', '리드', '##댄', '##서', '##로', '데뷔', '##한', '그', '##는', '2021', '##년', '3', '##월', '싱글', '앨범', 'R', '##로', '데뷔', '##했', '##다', '.', '빌보드', '글로벌', '200', '##은', '솔로', '##이자', '그룹', '##의', '멤버', '##이자', 'K', '##팝', '솔로', '##이스트', '##가', '24', '##시간', '동안', '가장', '많이', '본', '유튜브', '뮤직비디오', '##이', '##다', '.', '[SEP]']
#  Visualizations For Start Position
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>96</b></text></td><td><text style="padding-right:2em"><b>96 (0.98)</b></text></td><td><text style="padding-right:2em"><b>뉴질랜드</b></text></td><td><text style="padding-right:2em"><b>4.19</b></text></td><td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [CLS]                    </font></mark><mark style="background-color: hsl(120, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> 로                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##제                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##는                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> 2016                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> ##년                    </font></mark><mark style="background-color: hsl(120, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> 8                    </font></mark><mark style="background-color: hsl(120, 75%, 96%); opacity:1.0;                     line-height:1.75"><font color="black"> ##월                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> 걸그룹                    </font></mark><mark style="background-color: hsl(120, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> Bl                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##ack                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##pi                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##n                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##k                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> ##로                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> 데뷔                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> ##했                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> ##을                    </font></mark><mark style="background-color: hsl(120, 75%, 96%); opacity:1.0;                     line-height:1.75 ...
#  Visualizations For End Position
# attributions_start_sum:    147
# all tokens:     147
# 0.998823344707489 0.9777883887290955
# [0.9992594122886658, 0.9988586902618408, 0.9992868304252625, 0.9986371397972107, 0.9988114833831787, 0.9989060163497925, 0.998823344707489] [0.9714639782905579, 0.9473617672920227, 0.6024073362350464, 0.9838355779647827, 0.8820470571517944, 0.562415361404419, 0.9777883887290955]
# positive : 로 ##제 ##는 2016 ##년 8 ##월 걸그룹 Bl ##ack ##pi ##n ##k 데뷔 ##했 ##을 때 어떤 역할 했 ##나 ##요 ? 로 ##제 ( ##ne Par ##k , 1997 ##년 2 ##월 ##일 ) 은 ##에 거주 ##하 ##는 한국 ##의 뉴질랜드 댄서 ##다 . 에서 호주 서 성장 ##한 로 ##제 2012 오디션 보고 한국 음반 ##사 계약 간 ##의 ##을 받 ##았 ##다 . 2016 ##년 8 ##월 ##의 리드 ##보 ##컬 겸 리드 ##댄 ##서 데뷔 2021 ##년 3 ##월 ##로 데뷔 ##했 ##다 . 200 ##은 솔로 ##이자 그룹 ##의 ##이자 솔로 ##이스트 ##가 뮤직비디오 ##이 ##다 .
# negative : ##로 ##을 R ##os ##an 11 ~ 한국 ##이 태어나 ##년 ##을 YG ##엔터테인먼트 ##와 ##해 4 ##년 훈련 걸그룹 핑크 ##로 ##한 그 ##는 싱글 앨범 R 빌보드 글로벌 멤버 K ##팝 24 ##시간 동안 가장 많이 본 유튜브
# should delete :  핑크 tensor(-0.1355, dtype=torch.float64) index =  94
# Question:  로제는 2016년 8월 걸그룹 Blackpink로 데뷔했을 때 어떤 역할을 했나요?
# Predicted Answer:  리드 ##보 ##컬 겸 리드 ##댄 ##서
# ['[CLS]', '로', '##제', '##는', '2016', '##년', '8', '##월', '걸그룹', 'Bl', '##ack', '##pi', '##n', '##k', '##로', '데뷔', '##했', '##을', '때', '어떤', '역할', '##을', '했', '##나', '##요', '?', '[SEP]', '로', '##제', '(', 'R', '##os', '##an', '##ne', 'Par', '##k', ',', '1997', '##년', '2', '##월', '11', '##일', '~', ')', '은', '한국', '##에', '거주', '##하', '##는', '한국', '##의', '뉴질랜드', '댄서', '##이', '##다', '.', '에서', '태어나', '호주', '서', '성장', '##한', '로', '##제', '2012', '##년', '오디션', '##을', '보고', '한국', '음반', '##사', 'YG', '##엔터테인먼트', '##와', '계약', '##해', '4', '##년', '간', '##의', '훈련', '##을', '받', '##았', '##다', '.', '2016', '##년', '8', '##월', '걸그룹', '의', '리드', '##보', '##컬', '겸', '리드', '##댄', '##서', '##로', '데뷔', '##한', '그', '##는', '2021', '##년', '3', '##월', '싱글', '앨범', 'R', '##로', '데뷔', '##했', '##다', '.', '빌보드', '글로벌', '200', '##은', '솔로', '##이자', '그룹', '##의', '멤버', '##이자', 'K', '##팝', '솔로', '##이스트', '##가', '24', '##시간', '동안', '가장', '많이', '본', '유튜브', '뮤직비디오', '##이', '##다', '.', '[SEP]']
#  Visualizations For Start Position
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>95</b></text></td><td><text style="padding-right:2em"><b>95 (1.00)</b></text></td><td><text style="padding-right:2em"><b>뉴질랜드</b></text></td><td><text style="padding-right:2em"><b>4.34</b></text></td><td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [CLS]                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> 로                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##제                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##는                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> 2016                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> ##년                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> 8                    </font></mark><mark style="background-color: hsl(120, 75%, 96%); opacity:1.0;                     line-height:1.75"><font color="black"> ##월                    </font></mark><mark style="background-color: hsl(120, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> 걸그룹                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> Bl                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##ack                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> ##pi                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##n                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##k                    </font></mark><mark style="background-color: hsl(0, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##로                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> 데뷔                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> ##했                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> ##을                    </font></mark><mark style="background-color: hsl(120, 75%, 95%); opacity:1.0;                     line-height:1.75"> ...
#  Visualizations For End Position
# attributions_start_sum:    146
# all tokens:     146
# 0.9997778534889221 0.9989797472953796
# [0.9992594122886658, 0.9988586902618408, 0.9992868304252625, 0.9986371397972107, 0.9988114833831787, 0.9989060163497925, 0.998823344707489, 0.9997778534889221] [0.9714639782905579, 0.9473617672920227, 0.6024073362350464, 0.9838355779647827, 0.8820470571517944, 0.562415361404419, 0.9777883887290955, 0.9989797472953796]
# ...
#  Visualizations For End Position
# attributions_start_sum:    135
# all tokens:     135
# 0.9996179342269897 0.996109664440155
# [0.9992594122886658, 0.9988586902618408, 0.9992868304252625, 0.9986371397972107, 0.9988114833831787, 0.9989060163497925, 0.998823344707489, 0.9997778534889221, 0.9998242259025574, 0.9998133778572083, 0.9998134970664978, 0.9998120665550232, 0.9998170733451843, 0.9997547268867493, 0.9996185302734375, 0.9994696974754333, 0.9995550513267517, 0.999518871307373, 0.9996179342269897] [0.9714639782905579, 0.9473617672920227, 0.6024073362350464, 0.9838355779647827, 0.8820470571517944, 0.562415361404419, 0.9777883887290955, 0.9989797472953796, 0.9988908171653748, 0.998388409614563, 0.9983945488929749, 0.998258650302887, 0.998214840888977, 0.9971509575843811, 0.9980964064598083, 0.9924299120903015, 0.9942459464073181, 0.9961852431297302, 0.996109664440155]
# positive : 로 ##제 ##는 2016 ##년 8 ##월 걸그룹 Bl ##ack ##pi ##n ##k 데뷔 ##했 때 어떤 역할 했 ##나 ? 로 ##제 ( R ##os ##an ##ne Par ##k ##년 2 ##월 일 ) 은 ##에 거주 ##하 ##는 한국 ##의 뉴질랜드 댄서 에서 태어나 호주 성장 ##한 로 ##제 2012 ##년 오디션 보고 음반 ##사 YG ##엔터테인먼트 계약 ##해 4 ##의 훈련 ##을 받 ##다 . 2016 ##년 8 ##월 걸그룹 의 리드 ##보 ##컬 겸 ##댄 ##서 그 2021 ##년 ##월 ##했 ##다 . 빌보드 글로벌 200 ##은 솔로 ##이자 그룹 ##의 멤버 ##이자 ##이스트 ##가 24 ##시간 동안 ##다 .
# negative : ##로 ##을 ##을 ##요 , 1997 ~ 한국 . 서 한국 ##년 간 ##았 리드 ##로 데뷔 ##는 3 싱글 앨범 데뷔 K ##팝 솔로 본 뮤직비디오 ##이
# should delete :  뮤직비디오 tensor(-0.0560, dtype=torch.float64) index =  130
# Question:  로제는 2016년 8월 걸그룹 Blackpink로 데뷔했을 때 어떤 역할을 했나요?
# Predicted Answer:  리드 ##보 ##컬 겸 리드 ##댄 ##서
# ['[CLS]', '로', '##제', '##는', '2016', '##년', '8', '##월', '걸그룹', 'Bl', '##ack', '##pi', '##n', '##k', '##로', '데뷔', '##했', '##을', '때', '어떤', '역할', '##을', '했', '##나', '##요', '?', '[SEP]', '로', '##제', '(', 'R', '##os', '##an', '##ne', 'Par', '##k', ',', '1997', '##년', '2', '##월', '일', '~', ')', '은', '한국', '##에', '거주', '##하', '##는', '한국', '##의', '뉴질랜드', '댄서', '.', '에서', '태어나', '호주', '서', '성장', '##한', '로', '##제', '2012', '##년', '오디션', '보고', '한국', '음반', '##사', 'YG', '##엔터테인먼트', '계약', '##해', '4', '##년', '간', '##의', '훈련', '##을', '받', '##았', '##다', '.', '2016', '##년', '8', '##월', '걸그룹', '의', '리드', '##보', '##컬', '겸', '리드', '##댄', '##서', '##로', '데뷔', '그', '##는', '2021', '##년', '3', '##월', '싱글', '앨범', '데뷔', '##했', '##다', '.', '빌보드', '글로벌', '200', '##은', '솔로', '##이자', '그룹', '##의', '멤버', '##이자', 'K', '##팝', '솔로', '##이스트', '##가', '24', '##시간', '동안', '본', '이다', '.', '[SEP]']
#  Visualizations For Start Position
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>90</b></text></td><td><text style="padding-right:2em"><b>90 (1.00)</b></text></td><td><text style="padding-right:2em"><b>뉴질랜드</b></text></td><td><text style="padding-right:2em"><b>5.17</b></text></td><td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [CLS]                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> 로                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> ##제                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> ##는                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> 2016                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> ##년                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> 8                    </font></mark><mark style="background-color: hsl(120, 75%, 96%); opacity:1.0;                     line-height:1.75"><font color="black"> ##월                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> 걸그룹                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> Bl                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##ack                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##pi                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> ##n                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> ##k                    </font></mark><mark style="background-color: hsl(0, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##로                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> 데뷔                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> ##했                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> ##을                    </font></mark><mark style="background-color: hsl(120, 75%, 95%); opacity:1.0;                     line-height:1.75"> ...
#  Visualizations For End Position
# attributions_start_sum:    133
# all tokens:     133
# 0.9995823502540588 0.9964486360549927
# [0.9992594122886658, 0.9988586902618408, 0.9992868304252625, 0.9986371397972107, 0.9988114833831787, 0.9989060163497925, 0.998823344707489, 0.9997778534889221, 0.9998242259025574, 0.9998133778572083, 0.9998134970664978, 0.9998120665550232, 0.9998170733451843, 0.9997547268867493, 0.9996185302734375, 0.9994696974754333, 0.9995550513267517, 0.999518871307373, 0.9996179342269897, 0.9995823502540588] [0.9714639782905579, 0.9473617672920227, 0.6024073362350464, 0.9838355779647827, 0.8820470571517944, 0.562415361404419, 0.9777883887290955, 0.9989797472953796, 0.9988908171653748, 0.998388409614563, 0.9983945488929749, 0.998258650302887, 0.998214840888977, 0.9971509575843811, 0.9980964064598083, 0.9924299120903015, 0.9942459464073181, 0.9961852431297302, 0.996109664440155, 0.9964486360549927]
# positive : 로 ##제 ##는 2016 ##년 8 ##월 걸그룹 Bl ##ack ##pi ##n ##k 데뷔 ##했 때 어떤 역할 했 ##나 ? 로 ##제 ( R ##os ##an ##ne Par ##k ##년 2 ##월 일 ) 은 한국 ##에 거주 ##하 ##는 한국 ##의 뉴질랜드 댄서 태어나 호주 성장 ##한 로 ##제 2012 ##년 오디션 보고 음반 ##사 YG ##엔터테인먼트 계약 ##해 4 ##의 훈련 ##을 받 ##다 . 2016 ##년 8 ##월 걸그룹 의 리드 ##보 ##컬 ##댄 ##서 ##로 그 2021 ##년 ##월 ##했 ##다 . 빌보드 글로벌 200 ##은 솔로 ##이자 그룹 ##의 멤버 ##이자 ##이스트 ##가 24 ##시간 동안 본
# negative : ##로 ##을 ##을 ##요 , 1997 ~ . 에서 서 한국 ##년 간 ##았 겸 리드 데뷔 ##는 3 싱글 앨범 데뷔 K ##팝 솔로 이다 .
# should delete :  . tensor(-0.0985, dtype=torch.float64) index =  131
# Question:  로제는 2016년 8월 걸그룹 Blackpink로 데뷔했을 때 어떤 역할을 했나요?
# Predicted Answer:  리드 ##보 ##컬 겸 리드 ##댄 ##서
# ['[CLS]', '로', '##제', '##는', '2016', '##년', '8', '##월', '걸그룹', 'Bl', '##ack', '##pi', '##n', '##k', '##로', '데뷔', '##했', '##을', '때', '어떤', '역할', '##을', '했', '##나', '##요', '?', '[SEP]', '로', '##제', '(', 'R', '##os', '##an', '##ne', 'Par', '##k', ',', '1997', '##년', '2', '##월', '일', '~', ')', '은', '한국', '##에', '거주', '##하', '##는', '한국', '##의', '뉴질랜드', '댄서', '.', '에서', '태어나', '호주', '서', '성장', '##한', '로', '##제', '2012', '##년', '오디션', '보고', '한국', '음반', '##사', 'YG', '##엔터테인먼트', '계약', '##해', '4', '##년', '간', '##의', '훈련', '##을', '받', '##았', '##다', '.', '2016', '##년', '8', '##월', '걸그룹', '의', '리드', '##보', '##컬', '겸', '리드', '##댄', '##서', '##로', '데뷔', '그', '##는', '2021', '##년', '3', '##월', '싱글', '앨범', '데뷔', '##했', '##다', '.', '빌보드', '글로벌', '200', '##은', '솔로', '##이자', '그룹', '##의', '멤버', '##이자', 'K', '##팝', '솔로', '##이스트', '##가', '24', '##시간', '동안', '본', '이다', '[SEP]']
#  Visualizations For Start Position
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>90</b></text></td><td><text style="padding-right:2em"><b>90 (1.00)</b></text></td><td><text style="padding-right:2em"><b>뉴질랜드</b></text></td><td><text style="padding-right:2em"><b>5.39</b></text></td><td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [CLS]                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> 로                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##제                    </font></mark><mark style="background-color: hsl(120, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> ##는                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> 2016                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> ##년                    </font></mark><mark style="background-color: hsl(120, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> 8                    </font></mark><mark style="background-color: hsl(120, 75%, 96%); opacity:1.0;                     line-height:1.75"><font color="black"> ##월                    </font></mark><mark style="background-color: hsl(120, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> 걸그룹                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> Bl                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##ack                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##pi                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> ##n                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> ##k                    </font></mark><mark style="background-color: hsl(0, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##로                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> 데뷔                    </font></mark><mark style="background-color: hsl(120, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> ##했                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> ##을                    </font></mark><mark style="background-color: hsl(120, 75%, 95%); opacity:1.0;                     line-height:1.75" ...
#  Visualizations For End Position
# attributions_start_sum:    132
# all tokens:     132
# 0.9995517134666443 0.9963756203651428
# [0.9992594122886658, 0.9988586902618408, 0.9992868304252625, 0.9986371397972107, 0.9988114833831787, 0.9989060163497925, 0.998823344707489, 0.9997778534889221, 0.9998242259025574, 0.9998133778572083, 0.9998134970664978, 0.9998120665550232, 0.9998170733451843, 0.9997547268867493, 0.9996185302734375, 0.9994696974754333, 0.9995550513267517, 0.999518871307373, 0.9996179342269897, 0.9995823502540588, 0.9995517134666443] [0.9714639782905579, 0.9473617672920227, 0.6024073362350464, 0.9838355779647827, 0.8820470571517944, 0.562415361404419, 0.9777883887290955, 0.9989797472953796, 0.9988908171653748, 0.998388409614563, 0.9983945488929749, 0.998258650302887, 0.998214840888977, 0.9971509575843811, 0.9980964064598083, 0.9924299120903015, 0.9942459464073181, 0.9961852431297302, 0.996109664440155, 0.9964486360549927, 0.9963756203651428]
# [0.9992594122886658, 0.9988586902618408, 0.9992868304252625, 0.9986371397972107, 0.9988114833831787, 0.9989060163497925, 0.998823344707489, 0.9997778534889221, 0.9998242259025574, 0.9998133778572083, 0.9998134970664978, 0.9998120665550232, 0.9998170733451843, 0.9997547268867493, 0.9996185302734375, 0.9994696974754333, 0.9995550513267517, 0.999518871307373, 0.9996179342269897, 0.9995823502540588, 0.9995517134666443] [0.9714639782905579, 0.9473617672920227, 0.6024073362350464, 0.9838355779647827, 0.8820470571517944, 0.562415361404419, 0.9777883887290955, 0.9989797472953796, 0.9988908171653748, 0.998388409614563, 0.9983945488929749, 0.998258650302887, 0.998214840888977, 0.9971509575843811, 0.9980964064598083, 0.9924299120903015, 0.9942459464073181, 0.9961852431297302, 0.996109664440155, 0.9964486360549927, 0.9963756203651428]
# [0.9853616952896118, 0.9731102287769318, 0.8008470833301544, 0.9912363588809967, 0.9404292702674866, 0.7806606888771057, 0.9883058667182922, 0.9993788003921509, 0.9993575215339661, 0.9991008937358856, 0.9991040229797363, 0.9990353584289551, 0.9990159571170807, 0.9984528422355652, 0.9988574683666229, 0.9959498047828674, 0.9969004988670349, 0.9978520572185516, 0.9978637993335724, 0.9980154931545258, 0.9979636669158936]
